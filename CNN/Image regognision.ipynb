# %%
from PIL import Image
from sklearn.cluster import KMeans

# %%
import os
os.chdir("C:\\Users\\Adhvaidh\\Desktop\\DSP 19\\python DSP\\30th Nov 2019 (Clustering)")

# %%
img=Image.open('dogs.jpeg')
img1=Image.open('tiger.png')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
import
