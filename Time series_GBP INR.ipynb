# %%
import os
os.chdir("C:\\Users\\Adhvaidh\\Desktop")

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv("MoneyMkt LIBOR EUR 3-MONTH DAILY.csv")

# %%
ds.tail()
# Out:
#            DATE    CLOSE
# 1995  11-May-20 -0.22457
# 1996  12-May-20 -0.23071
# 1997  13-May-20 -0.24329
# 1998  14-May-20 -0.25800
# 1999  15-May-20 -0.26300

# %%
ds['DATE']=pd.to_datetime(ds['DATE'])

# %%
ds.head()
# Out:
#         DATE    CLOSE
# 0 2012-06-20  0.56686
# 1 2012-06-21  0.56479
# 2 2012-06-22  0.55907
# 3 2012-06-25  0.55679
# 4 2012-06-26  0.55621

# %%
ds.set_index('DATE', inplace=True)

# %%
ds.head()
# Out:
#               CLOSE
# DATE
# 2012-06-20  0.56686
# 2012-06-21  0.56479
# 2012-06-22  0.55907
# 2012-06-25  0.55679
# 2012-06-26  0.55621

# %%
ds.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp=seasonal_decompose(ds['CLOSE'], freq=12)  
decomp.plot()

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(ds['CLOSE'])
# Out:
# (-2.861985468184029,
#  0.04995051956733657,
#  8,
#  1991,
#  {'1%': -3.4336386745240652,
#   '5%': -2.8629927557359443,
#   '10%': -2.5675433856598793},
#  -15560.021342070435)

# %%
def adf_chec(time_series):
    result=adfuller(time_series)
    print("Augmented Dickey fuller test")
    labels=['ADF Test Statistic', 'P-value', '#Lags', 'No of obs.']
    for value, label in zip(result, labels):
        print(label + ':' + str(value))
    if result[1]<=0.05:
        print('Strong evidence against null hypothesis, timeseries is stationery')
    else: 
        print('Weak evidence against null hypothesis, timeseries is non-stationery')

# %%
adf_chec(ds['CLOSE'])
# Out:
# Augmented Dickey fuller test
# ADF Test Statistic:-2.861985468184029
# P-value:0.04995051956733657
# #Lags:8
# No of obs.:1991
# Strong evidence against null hypothesis, timeseries is stationery

# %%
#p=0;d=1;q=0

# %%
ds['Seasonal Difference']=ds['CLOSE']-ds['CLOSE'].shift(12)

# %%
ds.head()
# Out:
#               CLOSE  Seasonal Difference
# DATE
# 2012-06-20  0.56686                  NaN
# 2012-06-21  0.56479                  NaN
# 2012-06-22  0.55907                  NaN
# 2012-06-25  0.55679                  NaN
# 2012-06-26  0.55621                  NaN

# %%
adf_chec(ds['Seasonal Difference'].dropna())
# Out:
# Augmented Dickey fuller test
# ADF Test Statistic:-7.449626324327166
# P-value:5.715988282575059e-11
# #Lags:25
# No of obs.:1962
# Strong evidence against null hypothesis, timeseries is stationery

# %%
#d=1, D=0

# %%
plot_acf(ds['Seasonal Difference'].dropna(), lags=12) #Q=6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-27296cc2d47f> in <module>
# ----> 1 plot_acf(ds['Seasonal Difference'].dropna(), lags=12) #Q=6
#
# NameError: name 'plot_acf' is not defined

# %%
plot_pacf(ds['Seasonal Difference'].dropna(), lags=12) #P=1

# %%
#Finally,       AR  I  MA
#      TREND :  1   1  1

#SEASONALITY :  1  0   6

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(ds['CLOSE'],order=(1,1,1), seasonal_order=(2,1,2,12))
results=model.fit()
# Out:
# C:\Users\Adhvaidh\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
ds['forecast']=results.predict(start=1700, end=2000, dynamic=True)
ds[['P','forecast']].plot()

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[ds.index[-1]+ DateOffset(days=x) for x in range(0,365)]

# %%
future_dates_df_1=pd.DataFrame(index=future_dates[1:], columns=ds.columns)
future_df_1=pd.concat([ds,future_dates_df_1])

# %%
future_dates_df_1
# Out:
#            Price Price First Diff Seasonal Difference forecast
# 2020-04-18   NaN              NaN                 NaN      NaN
# 2020-04-19   NaN              NaN                 NaN      NaN
# 2020-04-20   NaN              NaN                 NaN      NaN
# 2020-04-21   NaN              NaN                 NaN      NaN
# 2020-04-22   NaN              NaN                 NaN      NaN
# 2020-04-23   NaN              NaN                 NaN      NaN
# 2020-04-24   NaN              NaN                 NaN      NaN
# 2020-04-25   NaN              NaN                 NaN      NaN
# 2020-04-26   NaN              NaN                 NaN      NaN
# 2020-04-27   NaN              NaN                 NaN      NaN
# 2020-04-28   NaN              NaN                 NaN      NaN
# 2020-04-29   NaN              NaN                 NaN      NaN
# 2020-04-30   NaN              NaN                 NaN      NaN
# 2020-05-01   NaN              NaN                 NaN      NaN
# 2020-05-02   NaN              NaN                 NaN      NaN
# 2020-05-03   NaN              NaN                 NaN      NaN
# 2020-05-04   NaN              NaN                 NaN      NaN
# 2020-05-05   NaN              NaN                 NaN      NaN
# 2020-05-06   NaN              NaN                 NaN      NaN
# 2020-05-07   NaN              NaN                 NaN      NaN
# 2020-05-08   NaN              NaN                 NaN      NaN
# 2020-05-09   NaN              NaN                 NaN      NaN
# 2020-05-10   NaN              NaN                 NaN      NaN
# 2020-05-11   NaN              NaN                 NaN      NaN
# 2020-05-12   NaN              NaN                 NaN      NaN
# 2020-05-13   NaN              NaN                 NaN      NaN
# 2020-05-14   NaN              NaN                 NaN      NaN
# 2020-05-15   NaN              NaN                 NaN      NaN
# 2020-05-16   NaN              NaN                 NaN      NaN
# 2020-05-17   NaN              NaN                 NaN      NaN
# ...          ...              ...                 ...      ...
# 2021-03-18   NaN              NaN                 NaN      NaN
# 2021-03-19   NaN              NaN                 NaN      NaN
# 2021-03-20   NaN              NaN                 NaN      NaN
# 2021-03-21   NaN              NaN                 NaN      NaN
# 2021-03-22   NaN              NaN                 NaN      NaN
# 2021-03-23   NaN              NaN                 NaN      NaN
# 2021-03-24   NaN              NaN                 NaN      NaN
# 2021-03-25   NaN              NaN                 NaN      NaN
# 2021-03-26   NaN              NaN                 NaN      NaN
# 2021-03-27   NaN              NaN                 NaN      NaN
# 2021-03-28   NaN              NaN                 NaN      NaN
# 2021-03-29   NaN              NaN                 NaN      NaN
# 2021-03-30   NaN              NaN                 NaN      NaN
# 2021-03-31   NaN              NaN                 NaN      NaN
# 2021-04-01   NaN              NaN                 NaN      NaN
# 2021-04-02   NaN              NaN                 NaN      NaN
# 2021-04-03   NaN              NaN                 NaN      NaN
# 2021-04-04   NaN              NaN                 NaN      NaN
# 2021-04-05   NaN              NaN                 NaN      NaN
# 2021-04-06   NaN              NaN                 NaN      NaN
# 2021-04-07   NaN              NaN                 NaN      NaN
# 2021-04-08   NaN              NaN                 NaN      NaN
# 2021-04-09   NaN              NaN                 NaN      NaN
# 2021-04-10   NaN              NaN                 NaN      NaN
# 2021-04-11   NaN              NaN                 NaN      NaN
# 2021-04-12   NaN              NaN                 NaN      NaN
# 2021-04-13   NaN              NaN                 NaN      NaN
# 2021-04-14   NaN              NaN                 NaN      NaN
# 2021-04-15   NaN              NaN                 NaN      NaN
# 2021-04-16   NaN              NaN                 NaN      NaN
#
# [364 rows x 4 columns]

# %%
future_df_1['forecast']=results.predict(start=1567, end=1932, dynamic=True)
future_df_1[['Price','forecast']].plot()
# Out:
# C:\Users\Adhvaidh\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:1960: ValueWarning: Dynamic prediction specified to begin during out-of-sample forecasting period, and so has no effect.
#   ' effect.', ValueWarning)

# %%
future_df_1.tail(-1565)
# Out:
#             Price  Price First Diff  Seasonal Difference  forecast
# 2020-04-18    NaN               NaN                  NaN       NaN
# 2020-04-19    NaN               NaN                  NaN       NaN
# 2020-04-20    NaN               NaN                  NaN       NaN
# 2020-04-21    NaN               NaN                  NaN       NaN
# 2020-04-22    NaN               NaN                  NaN  1.249262
# 2020-04-23    NaN               NaN                  NaN  1.250302
# 2020-04-24    NaN               NaN                  NaN  1.251291
# 2020-04-25    NaN               NaN                  NaN       NaN
# 2020-04-26    NaN               NaN                  NaN       NaN
# 2020-04-27    NaN               NaN                  NaN  1.250392
# 2020-04-28    NaN               NaN                  NaN  1.249751
# 2020-04-29    NaN               NaN                  NaN  1.249072
# 2020-04-30    NaN               NaN                  NaN  1.248502
# 2020-05-01    NaN               NaN                  NaN  1.247310
# 2020-05-02    NaN               NaN                  NaN       NaN
# 2020-05-03    NaN               NaN                  NaN       NaN
# 2020-05-04    NaN               NaN                  NaN  1.246763
# 2020-05-05    NaN               NaN                  NaN  1.246536
# 2020-05-06    NaN               NaN                  NaN  1.244583
# 2020-05-07    NaN               NaN                  NaN  1.243164
# 2020-05-08    NaN               NaN                  NaN  1.242391
# 2020-05-09    NaN               NaN                  NaN       NaN
# 2020-05-10    NaN               NaN                  NaN       NaN
# 2020-05-11    NaN               NaN                  NaN  1.243079
# 2020-05-12    NaN               NaN                  NaN  1.242639
# 2020-05-13    NaN               NaN                  NaN  1.242624
# 2020-05-14    NaN               NaN                  NaN  1.241957
# 2020-05-15    NaN               NaN                  NaN  1.243818
# 2020-05-16    NaN               NaN                  NaN       NaN
# 2020-05-17    NaN               NaN                  NaN       NaN
# ...           ...               ...                  ...       ...
# 2021-03-18    NaN               NaN                  NaN  1.198514
# 2021-03-19    NaN               NaN                  NaN  1.197896
# 2021-03-20    NaN               NaN                  NaN       NaN
# 2021-03-21    NaN               NaN                  NaN       NaN
# 2021-03-22    NaN               NaN                  NaN  1.196470
# 2021-03-23    NaN               NaN                  NaN  1.195456
# 2021-03-24    NaN               NaN                  NaN  1.195074
# 2021-03-25    NaN               NaN                  NaN  1.196018
# 2021-03-26    NaN               NaN                  NaN  1.196270
# 2021-03-27    NaN               NaN                  NaN       NaN
# 2021-03-28    NaN               NaN                  NaN       NaN
# 2021-03-29    NaN               NaN                  NaN  1.195927
# 2021-03-30    NaN               NaN                  NaN  1.195276
# 2021-03-31    NaN               NaN                  NaN  1.196036
# 2021-04-01    NaN               NaN                  NaN  1.196444
# 2021-04-02    NaN               NaN                  NaN  1.195927
# 2021-04-03    NaN               NaN                  NaN       NaN
# 2021-04-04    NaN               NaN                  NaN       NaN
# 2021-04-05    NaN               NaN                  NaN  1.195918
# 2021-04-06    NaN               NaN                  NaN  1.195310
# 2021-04-07    NaN               NaN                  NaN  1.193873
# 2021-04-08    NaN               NaN                  NaN  1.192852
# 2021-04-09    NaN               NaN                  NaN  1.192462
# 2021-04-10    NaN               NaN                  NaN       NaN
# 2021-04-11    NaN               NaN                  NaN       NaN
# 2021-04-12    NaN               NaN                  NaN  1.193401
# 2021-04-13    NaN               NaN                  NaN  1.193639
# 2021-04-14    NaN               NaN                  NaN  1.193303
# 2021-04-15    NaN               NaN                  NaN  1.192652
# 2021-04-16    NaN               NaN                  NaN  1.193433
#
# [364 rows x 4 columns]

# %%
future_df_2=future_df_1.drop(['Price','Price First Diff','Seasonal Difference'],axis=1)

# %%
future_df_2.tail(-1565)
# Out:
#             forecast
# 2020-04-18       NaN
# 2020-04-19       NaN
# 2020-04-20       NaN
# 2020-04-21       NaN
# 2020-04-22  1.249262
# 2020-04-23  1.250302
# 2020-04-24  1.251291
# 2020-04-25       NaN
# 2020-04-26       NaN
# 2020-04-27  1.250392
# 2020-04-28  1.249751
# 2020-04-29  1.249072
# 2020-04-30  1.248502
# 2020-05-01  1.247310
# 2020-05-02       NaN
# 2020-05-03       NaN
# 2020-05-04  1.246763
# 2020-05-05  1.246536
# 2020-05-06  1.244583
# 2020-05-07  1.243164
# 2020-05-08  1.242391
# 2020-05-09       NaN
# 2020-05-10       NaN
# 2020-05-11  1.243079
# 2020-05-12  1.242639
# 2020-05-13  1.242624
# 2020-05-14  1.241957
# 2020-05-15  1.243818
# 2020-05-16       NaN
# 2020-05-17       NaN
# ...              ...
# 2021-03-18  1.198514
# 2021-03-19  1.197896
# 2021-03-20       NaN
# 2021-03-21       NaN
# 2021-03-22  1.196470
# 2021-03-23  1.195456
# 2021-03-24  1.195074
# 2021-03-25  1.196018
# 2021-03-26  1.196270
# 2021-03-27       NaN
# 2021-03-28       NaN
# 2021-03-29  1.195927
# 2021-03-30  1.195276
# 2021-03-31  1.196036
# 2021-04-01  1.196444
# 2021-04-02  1.195927
# 2021-04-03       NaN
# 2021-04-04       NaN
# 2021-04-05  1.195918
# 2021-04-06  1.195310
# 2021-04-07  1.193873
# 2021-04-08  1.192852
# 2021-04-09  1.192462
# 2021-04-10       NaN
# 2021-04-11       NaN
# 2021-04-12  1.193401
# 2021-04-13  1.193639
# 2021-04-14  1.193303
# 2021-04-15  1.192652
# 2021-04-16  1.193433
#
# [364 rows x 1 columns]

# %%
future_df_2=future_df_2.tail(-1565)
